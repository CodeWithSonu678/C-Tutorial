# %% [markdown]
# <a href="https://colab.research.google.com/github/CodeWithSonu678/C-Tutorial/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome to Colab!

# %% [markdown]
# Hlo I am going to print hello world.

# %%
print("hello")
# Out:
# hello

# %%
Message = "hello bro "
print(Message)
# Out:
# hello bro
